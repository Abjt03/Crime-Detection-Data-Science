# %% [markdown]
# #### Import Packages :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from pandasql import sqldf
from functools import reduce

pd.set_option('display.max_rows', 200)
print('Packages Loaded')

mysql = lambda q: sqldf(q, globals())
# Out:
# Packages Loaded

# %% [markdown]
# #### Read CSV File :

# %%
Crime_Data = pd.read_csv('Clean_Boston_Crime_Data.csv')
Crime_Data = Crime_Data.astype({'Code':'int32', 'Offense':'string', 'Date':'datetime64[ns]', 'Year':'int32', 'Month':'int32', 'Lat':'float64', 'Long':'float64'})
Crime_Data.sort_values(by = ['Date'], inplace = True)
Crime_Data
# Out:
#         Code                          Offense       Date  Year  Month  \
# 157611  2670  Harassment/ criminal harassment 2019-01-01  2019      1
# 157845  1402                        Vandalism 2019-01-01  2019      1
# 148969  1106  Fraud - credit card / atm fraud 2019-01-01  2019      1
# 157768  1107            Fraud - impersonation 2019-01-01  2019      1
# 147870  1106  Fraud - credit card / atm fraud 2019-01-01  2019      1
# ...      ...                              ...        ...   ...    ...
# 158098  2905      Val - violation of auto law 2022-04-15  2022      4
# 158097  3114             Investigate property 2022-04-15  2022      4
# 158096  2907  Val - operating after rev/susp. 2022-04-15  2022      4
# 158095  3802   M/v accident - property damage 2022-04-15  2022      4
# 158094  3114             Investigate property 2022-04-15  2022      4
#
#               Lat       Long
# 157611  42.297555 -71.059709
# 157845  42.377499 -71.058774
# 148969  42.351935 -71.060486
# 157768  42.341288 -71.054679
# 147870  42.339542 -71.069409
# ...           ...        ...
# 158098  42.343960 -71.065930
# 158097  42.362903 -71.137378
# 158096  42.312158 -71.070568
# 158095  42.349322 -71.072102
# 158094  42.355807 -71.149322
#
# [176735 rows x 7 columns]

# %% [markdown]
# #### Finding Crimes to be plotted :

# %%
query = '''
SELECT Code, Offense, COUNT(Code) FROM Crime_Data
GROUP BY Code
ORDER BY COUNT(Code) DESC
''' 
mysql(query)
# Out:
#      Code                                            Offense  COUNT(Code)
# 0    3115                                 Investigate person        14963
# 1    3831              M/v - leaving scene - property damage        10441
# 2    3005                                        Sick assist        10048
# 3    3114                               Investigate property         8380
# 4    1402                                          Vandalism         8032
# 5    3410                                Towed motor vehicle         7291
# 6     801                                   Assault - simple         6905
# 7     614              Larceny theft from mv - non-accessory         5625
# 8    3006                      Sick/injured/medical - person         5602
# 9     613                                Larceny shoplifting         5592
# 10   3201                           Property - lost/ missing         4899
# 11   3802                     M/v accident - property damage         4788
# 12    617                        Larceny theft from building         4213
# 13   2647                          Threats to do bodily harm         4202
# 14    423                               Assault - aggravated         4019
# 15   3301                                     Verbal dispute         3907
# 16   1810       Drugs - possession/ sale/ manufacturing/ use         3751
# 17    619                                 Larceny all others         3593
# 18   1102                    Fraud - false pretense / scheme         3159
# 19   3801                               M/v accident - other         2944
# 20   2670                    Harassment/ criminal harassment         2770
# 21   2905                        Val - violation of auto law         2658
# 22    724                                         Auto theft         2403
# 23   3502                           Missing person - located         2338
# 24   3803                     M/v accident - personal injury         2315
# 25    520                     Burglary - residential - force         2130
# 26   3207                                   Property - found         2080
# 27    301                                            Robbery         1864
# 28   1832                 Sick assist - drug related illness         1832
# 29    616                           Larceny theft of bicycle         1821
# 30   1107                              Fraud - impersonation         1575
# 31   1831               Drugs - sick assist - other narcotic         1502
# 32   3018                      Sick/injured/medical - police         1344
# 33   3007                                       Sudden death         1293
# 34   1106                    Fraud - credit card / atm fraud         1206
# 35    615            Larceny theft of mv parts & accessories         1201
# 36   3108                                        Fire report         1091
# 37   1108                                    Fraud - welfare         1085
# 38   3820       M/v accident - involving pedestrian - injury         1055
# 39   2907                    Val - operating after rev/susp.         1040
# 40    540                      Burglary - commerical - force         1024
# 41   3001                                Death investigation          986
# 42   3501                                     Missing person          978
# 43   2610                                        Trespassing          855
# 44   3112                                  Landlord - tenant          817
# 45   3111                          License premise violation          797
# 46   3126         Warrant arrest - outside of boston warrant          764
# 47   3830              M/v - leaving scene - personal injury          710
# 48   3110                            Service to other agency          675
# 49   2662                          Ballistics evidence/found          672
# 50   3106                       Property - accidental damage          630
# 51    706                  Auto theft - motorcycle / scooter          581
# 52    735  Recovered - mv recovered in boston (stolen out...          544
# 53   1001                           Forgery / counterfeiting          528
# 54   3805                      M/v accident - police vehicle          506
# 55   3807                  M/v accident - other city vehicle          503
# 56   3810          M/v accident - involving bicycle - injury          413
# 57   3503            Missing person - not reported - located          402
# 58   2403  Disturbing the peace/ disorderly conduct/ gath...          394
# 59   1109                                       Fraud - wire          380
# 60   3119              Firearm/weapon - found or confiscated          375
# 61   3205                                  M/v plates - lost          362
# 62   3402        Animal incidents (dog bites, lost dog, etc)          352
# 63   3130                                     Search warrant          297
# 64   1300  Stolen property - buying / receiving / possessing          295
# 65   2646                Liquor/alcohol - drinking in public          264
# 66    727                 Auto theft - leased/rented vehicle          262
# 67   2604                             Extortion or blackmail          241
# 68   3821    M/v accident - involving pedestrian - no injury          237
# 69   2914           Val - operating w/o authorization lawful          230
# 70   2101        Operating under the influence (oui) alcohol          228
# 71   1415                                           Graffiti          225
# 72   3304                        Noisy party/radio-no arrest          209
# 73   2007          Violation - restraining order (no arrest)          204
# 74   3625                   Dangerous or hazardous condition          190
# 75   2657                         Violation - city ordinance          170
# 76   3811       M/v accident - involving bicycle - no injury          168
# 77    611                                Larceny pick-pocket          137
# 78    641          Breaking and entering (b&e) motor vehicle          125
# 79   3008                          Suicide / suicide attempt          117
# 80   1201                                       Embezzlement          113
# 81   2632                                       Evading fare          111
# 82   3202                       Property - lost then located          101
# 83   2612                          Fire report/alarm - false           98
# 84    111                Murder, non-negligient manslaughter           93
# 85   3116                        Harbor incident / violation           83
# 86   2671            Violation - harassment prevention order           79
# 87    736  Recovered - mv recovered in boston (stolen in ...           79
# 88   2660                                      Other offense           78
# 89    531  Breaking and entering (b&e) motor vehicle (no ...           72
# 90   2619                              Fugitive from justice           66
# 91    900                                              Arson           65
# 92   1304                   Property - stolen then recovered           64
# 93   2401                                             Affray           58
# 94   1825            Drugs - possession of drug paraphanalia           55
# 95   3122                                 Aircraft incidents           51
# 96   3170                               Intimidating witness           49
# 97   2648                                        Bomb threat           42
# 98    600                    Migrated report - other larceny           41
# 99   3004                     Injury bicycle no m/v involved           34
# 100  2613                                       Animal abuse           34
# 101  1602                          Prostitution - soliciting           33
# 102  1800  Migrated report - drugs - possession/manufactu...           29
# 103  2102          Operating under the influence (oui) drugs           27
# 104  2618                     Explosives - possession or use           26
# 105  2006                Viol. of restraining order w arrest           25
# 106  2622         Kidnapping/custodial kidnapping/ abduction           22
# 107  2608         Child requiring assistance (fomerly chins)           20
# 108  2204                               Liquor law violation           20
# 109  3029               Prisoner - suicide / suicide attempt           19
# 110  3123                    Explosives - turned in or found           18
# 111  3300                   Migrated report - other part iii           17
# 112   800        Migrated report - assault/assault & battery           17
# 113  2616                    Possession of burglarious tools           15
# 114   400  Migrated report - aggravated assault/aggravate...           15
# 115  3305                                        Drunkenness           11
# 116  2600                    Migrated report - other part ii           11
# 117  3403                   Protective custody / safekeeping           10
# 118  3203                              Firearm/weapon - lost            8
# 119  2628                                Obscene phone calls            8
# 120   802                           Assault simple - battery            8
# 121  2642                                  Truancy / runaway            7
# 122  1601                                       Prostitution            7
# 123   500   Migrated report - burglary/breaking and entering            7
# 124   413                     Assault - aggravated - battery            7
# 125  3000              Migrated report - death investigation            5
# 126  2900               Migrated report - auto law violation            5
# 127   300                          Migrated report - robbery            5
# 128  3200               Migrated report - investigate person            4
# 129  3100             Migrated report - investigate property            4
# 130  2950              Migrated report - motor vehicle crash            4
# 131  1500                Migrated report - weapons violation            4
# 132   530          Breaking and entering (b&e) motor vehicle            4
# 133   522                  Burglary - residential - no force            4
# 134  1842               Drugs - poss class a - heroin, etc.             3
# 135  1100                            Migrated report - fraud            3
# 136   618                 Larceny theft from coin-op machine            3
# 137  3016         Firearm/weapon - accidental injury / death            2
# 138  2400  Migrated report - affray/disturbing the peace/...            2
# 139  1843     Drugs - poss class b - intent to mfr dist disp            2
# 140  1400  Migrated report - vandalism/destruction of pro...            2
# 141  1000           Migrated report - counterfeiting/forgery            2
# 142   700                       Migrated report - auto theft            2
# 143   650                  Migrated report - larceny from mv            2
# 144   121                Manslaughter - vehicle - negligence            2
# 145  3350      Migrated report - injured/medical/sick assist            1
# 146  2672                                 Biological threats            1
# 147  2629                                         Harassment            1
# 148  2500                       Migrated report - kidnapping            1
# 149  1849               Drugs - poss class b - cocaine, etc.            1
# 150  1848     Drugs - poss class d - intent to mfr dist disp            1
# 151  1844                               Drugs - poss class c            1
# 152  1841     Drugs - poss class a - intent to mfr dist disp            1
# 153  1603              Prostitution - assisting or promoting            1
# 154  1200                     Migrated report - embezzlement            1
# 155   990                               Justifiable homicide            1
# 156   541                    Burglary - commerical - attempt            1
# 157   122                          Manslaughter - negligence            1
# 158   100                Migrated report - criminal homicide            1

# %% [markdown]
# ##### Here, we choose the following 5 crimes :
# 1. Assault
# 2. Fraud
# 3. Drugs
# 4. Vandalism

# %% [markdown]
# #### Line Graph Dataframe Creation :

# %%
query = '''
SELECT Date, Count(Offense) AS "Count_F"
FROM Crime_Data
WHERE Offense LIKE "%Fraud%"
GROUP BY Date
ORDER BY Date
'''
Fraud = mysql(query)
Fraud
# Out:
#                            Date  Count_F
# 0    2019-01-01 00:00:00.000000        7
# 1    2019-01-10 00:00:00.000000        1
# 2    2019-01-17 00:00:00.000000        1
# 3    2019-01-21 00:00:00.000000        1
# 4    2019-02-01 00:00:00.000000        1
# ..                          ...      ...
# 995  2022-04-10 00:00:00.000000        1
# 996  2022-04-11 00:00:00.000000       10
# 997  2022-04-12 00:00:00.000000        6
# 998  2022-04-13 00:00:00.000000        3
# 999  2022-04-14 00:00:00.000000        1
#
# [1000 rows x 2 columns]

# %%
query = '''
SELECT Date, Count(Offense) AS "Count_A"
FROM Crime_Data
WHERE Offense LIKE "%Assault%"
GROUP BY Date
ORDER BY Date
'''
Assault = mysql(query)
Assault
# Out:
#                            Date  Count_A
# 0    2019-01-02 00:00:00.000000        2
# 1    2019-01-16 00:00:00.000000        1
# 2    2019-01-19 00:00:00.000000        1
# 3    2019-01-21 00:00:00.000000        1
# 4    2019-02-20 00:00:00.000000        1
# ..                          ...      ...
# 971  2022-04-10 00:00:00.000000       11
# 972  2022-04-11 00:00:00.000000       10
# 973  2022-04-12 00:00:00.000000       11
# 974  2022-04-13 00:00:00.000000       16
# 975  2022-04-14 00:00:00.000000       16
#
# [976 rows x 2 columns]

# %%
query = '''
SELECT Date, Count(Offense) AS "Count_D"
FROM Crime_Data
WHERE Offense LIKE "%Drugs%"
GROUP BY Date
ORDER BY Date
'''
Drugs = mysql(query)
Drugs
# Out:
#                            Date  Count_D
# 0    2019-02-08 00:00:00.000000        1
# 1    2019-03-01 00:00:00.000000        1
# 2    2019-03-10 00:00:00.000000        1
# 3    2019-03-15 00:00:00.000000        1
# 4    2019-03-23 00:00:00.000000        1
# ..                          ...      ...
# 857  2022-04-09 00:00:00.000000        2
# 858  2022-04-11 00:00:00.000000        5
# 859  2022-04-12 00:00:00.000000        1
# 860  2022-04-13 00:00:00.000000        4
# 861  2022-04-14 00:00:00.000000        5
#
# [862 rows x 2 columns]

# %%
query = '''
SELECT Date, Count(Offense) AS "Count_V"
FROM Crime_Data
WHERE Offense LIKE "%Vandalism%"
GROUP BY Date
ORDER BY Date
'''
Vandalism = mysql(query)
Vandalism
# Out:
#                            Date  Count_V
# 0    2019-01-01 00:00:00.000000        1
# 1    2019-01-23 00:00:00.000000        1
# 2    2019-03-01 00:00:00.000000        1
# 3    2019-04-16 00:00:00.000000        1
# 4    2019-05-01 00:00:00.000000        1
# ..                          ...      ...
# 943  2022-04-10 00:00:00.000000        3
# 944  2022-04-11 00:00:00.000000       10
# 945  2022-04-12 00:00:00.000000        5
# 946  2022-04-13 00:00:00.000000        8
# 947  2022-04-14 00:00:00.000000        5
#
# [948 rows x 2 columns]

# %%
frames = [Assault, Fraud, Drugs, Vandalism]
Plot_df = reduce(lambda  left,right: pd.merge(left, right, on=['Date'], how='outer'), frames).dropna()
Plot_df.Date = pd.to_datetime(Plot_df.Date).dt.normalize()
Plot_df.set_index('Date', inplace = True)
Plot_df
# Out:
#             Count_A  Count_F  Count_D  Count_V
# Date
# 2019-09-12      1.0      1.0      1.0      1.0
# 2019-09-26      2.0      4.0      1.0      2.0
# 2019-09-27      4.0      6.0      2.0      4.0
# 2019-09-29     16.0      4.0      3.0     18.0
# 2019-09-30     16.0      8.0     10.0      9.0
# ...             ...      ...      ...      ...
# 2022-04-09     14.0      2.0      2.0     10.0
# 2022-04-11     10.0     10.0      5.0     10.0
# 2022-04-12     11.0      6.0      1.0      5.0
# 2022-04-13     16.0      3.0      4.0      8.0
# 2022-04-14     16.0      1.0      5.0      5.0
#
# [825 rows x 4 columns]

# %% [markdown]
# Here, we assume that the officers were getting used to the new database crime record system and **ignore the first nine months of 2019** and since April 2022 was partly over when this database was retrieved, we **ignore April 2022**

# %%
Plot_df = Plot_df[8:-1]
Plot_df
# Out:
#             Count_A  Count_F  Count_D  Count_V
# Date
# 2019-10-04     19.0     17.0      7.0      6.0
# 2019-10-05     21.0      6.0      6.0     12.0
# 2019-10-06     17.0      4.0      4.0     10.0
# 2019-10-07     21.0     14.0      7.0      6.0
# 2019-10-08     19.0      6.0      5.0      4.0
# ...             ...      ...      ...      ...
# 2022-04-08     14.0      5.0      4.0     12.0
# 2022-04-09     14.0      2.0      2.0     10.0
# 2022-04-11     10.0     10.0      5.0     10.0
# 2022-04-12     11.0      6.0      1.0      5.0
# 2022-04-13     16.0      3.0      4.0      8.0
#
# [816 rows x 4 columns]

# %% [markdown]
# #### Plotting Line Graph :

# %%
plt.figure(figsize = (22,14))
plt.title('Crimes taking place in 2019-2022')
sns.lineplot(data = Plot_df)
plt.ylabel('Crime Incidents')
# Out:
# Text(0, 0.5, 'Crime Incidents')

# %% [markdown]
# #### Scatter Plot Dataframe Creation :

# %%
Fraud1 = Fraud
Fraud1.rename(columns = {'Count_F':'Count'}, inplace = True)
Fraud1['Offense'] = 'Fraud'

Assault1 = Assault
Assault1.rename(columns = {'Count_A':'Count'}, inplace = True)
Assault1['Offense'] = 'Assault'

Drugs1 = Drugs
Drugs1.rename(columns = {'Count_D':'Count'}, inplace = True)
Drugs1['Offense'] = 'Drugs'

Vandalism1 = Vandalism
Vandalism1.rename(columns = {'Count_V':'Count'}, inplace = True)
Vandalism1['Offense'] = 'Vandalism'

frames = [Assault1, Fraud1, Drugs1, Vandalism1]
SPlot_df = pd.concat(frames)

# %%
SPlot_df.Date = pd.to_datetime(SPlot_df.Date).dt.normalize()
SPlot_df.sort_values(by = 'Date', inplace = True)
SPlot_df.reset_index(inplace = True, drop = True)
SPlot_df
# Out:
#            Date  Count    Offense
# 0    2019-01-01      7      Fraud
# 1    2019-01-01      1  Vandalism
# 2    2019-01-02      2    Assault
# 3    2019-01-10      1      Fraud
# 4    2019-01-16      1    Assault
# ...         ...    ...        ...
# 3781 2022-04-13      3      Fraud
# 3782 2022-04-14     16    Assault
# 3783 2022-04-14      1      Fraud
# 3784 2022-04-14      5      Drugs
# 3785 2022-04-14      5  Vandalism
#
# [3786 rows x 3 columns]

# %%
SPlot_df.to_csv('Scatterplot.csv')

# %% [markdown]
# #### Plotting Scatter Plot :

# %%
plt.figure(figsize = (20, 15))
sns.scatterplot(x = SPlot_df.Date, y = SPlot_df.Count, hue = SPlot_df.Offense)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Count'>
